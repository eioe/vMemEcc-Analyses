# %%
from os import path as op
import sys
import numpy as np
import mne
import autoreject

from library import config, helpers

# %%
def get_ica_weights(subID, data_, ica_from_disc = False, reject=None,
                    method='picard', fit_params=None, save_to_disc=True):
    ### Load ICA data (after comp rejection)?
    if ica_from_disc:
        ica = mne.preprocessing.read_ica(fname=op.join(config.paths['03_preproc-ica'], subID + '-ica.fif'))
    else:
        # data_.drop_bad(reject=reject)
        ica = mne.preprocessing.ICA(method=method, 
                                    fit_params=fit_params)
        ica.fit(data_)
        if save_to_disc:
            ica.save(fname=op.join(config.paths['03_preproc-ica'], subID + '-ica.fif.'))
    return ica

# %%
subID = 'VME_S20'
# get BP [1; 40Hz] filtered data to train ICA:
data_forica = helpers.load_data(subID + '-stimon',
                                config.paths['02_epochs'],
                                append='-epo')
ica_raw = get_ica_weights(subID,
                      data_forica,
                      ica_from_disc=False,
                      #method='infomax',
                      #fit_params={'extended':True},
                      save_to_disc=False)
# Out:
# Reading /raven/ptmp/fklotzsche/Experiments/vMemEcc/Data2022/DataMNE/EEG/02_epochs/VME_S20-stimon-epo.fif ...
#     Found the data of interest:
#         t =    -600.00 ...    2300.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /raven/ptmp/fklotzsche/Experiments/vMemEcc/Data2022/DataMNE/EEG/03_preproc-ica/VME_S20-ica.fif ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55983/229212721.py in <module>
#       4                                 config.paths['02_epochs'],
#       5                                 append='-epo')
# ----> 6 ica_raw = get_ica_weights(subID,
#       7                       data_forica,
#       8                       ica_from_disc=True,
#
# /tmp/ipykernel_55983/3419621054.py in get_ica_weights(subID, data_, ica_from_disc, reject, method, fit_params, save_to_disc)
#       3     ### Load ICA data (after comp rejection)?
#       4     if ica_from_disc:
# ----> 5         ica = mne.preprocessing.read_ica(fname=op.join(config.paths['03_preproc-ica'], subID + '-ica.fif'))
#       6     else:
#       7         # data_.drop_bad(reject=reject)
#
# <decorator-gen-405> in read_ica(fname, verbose)
#
# ~/conda-envs/mne/lib/python3.9/site-packages/mne/preprocessing/ica.py in read_ica(fname, verbose)
#    2438
#    2439     logger.info('Reading %s ...' % fname)
# -> 2440     fid, tree, _ = fiff_open(fname)
#    2441
#    2442     try:
#
# <decorator-gen-5> in fiff_open(fname, preload, verbose)
#
# ~/conda-envs/mne/lib/python3.9/site-packages/mne/io/open.py in fiff_open(fname, preload, verbose)
#     122         A list of tags.
#     123     """
# --> 124     fid = _fiff_get_fid(fname)
#     125     try:
#     126         return _fiff_open(fname, fid, preload)
#
# ~/conda-envs/mne/lib/python3.9/site-packages/mne/io/open.py in _fiff_get_fid(fname)
#      51         else:
#      52             logger.debug('Using normal I/O')
# ---> 53             fid = open(fname, "rb")  # Open in binary mode
#      54     return fid
#      55
#
# FileNotFoundError: [Errno 2] No such file or directory: '/raven/ptmp/fklotzsche/Experiments/vMemEcc/Data2022/DataMNE/EEG/03_preproc-ica/VME_S20-ica.fif'

# %%
# %matplotlib qt
picks = ['HEOG', 'VEOG', 'ICA001', 'ICA002', 'ICA003']
i2 = ica_raw.copy()
i2.exclude = np.arange(9,60)
i2.plot_sources(data_forica)
# Out:
# Not setting metadata
# Not setting metadata
# 720 matching events found
# /tmp/ipykernel_55983/4012150525.py:5: RuntimeWarning: More events than default colors available. You should pass a list of unique colors.
#   i2.plot_sources(data_forica)
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# <MNEBrowseFigure size 1594x964 with 4 Axes>

# %%
ica_raw.plot_properties(data_forica)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# [<Figure size 700x600 with 6 Axes>,
#  <Figure size 700x600 with 6 Axes>,
#  <Figure size 700x600 with 6 Axes>,
#  <Figure size 700x600 with 6 Axes>,
#  <Figure size 700x600 with 6 Axes>]

# %%
picks = ['eeg', 'eog']
data_forica.copy().apply_baseline((-0.4,0)).\
    filter(picks=['eog'], l_freq=1, h_freq = 40).\
    plot(picks=picks, scalings={'eeg':100e-6, 'eog':100e-6})
# Out:
# Applying baseline correction (mode: mean)
# Filtering a subset of channels. The highpass and lowpass values in the measurement info will not be updated.
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 1651 samples (3.302 sec)
# /tmp/ipykernel_55983/412852097.py:2: RuntimeWarning: filter_length (1651) is longer than the signal (1451), distortion is likely. Reduce filter length or filter a longer signal.
#   data_forica.copy().apply_baseline((-0.4,0)).\
# <MNEBrowseFigure size 1594x964 with 4 Axes>
# Dropped 0 epochs:
# Channels marked as bad: none
